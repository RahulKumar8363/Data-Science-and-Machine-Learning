# %% [markdown]
# ### Varaible

# %% [markdown]
# Varaible are fundamental elements in programming used to store data that can referenced and manipulated in a program . In python, Varaible are created when you assign a value to then, and they do not need explicit declaration to reserve memory space. The declaration happen automatically when you assign a valuse to a variable .
#
# Video outline:
# . Introduction to variable
# . Declaring and assigning varaible
# . Understanding Varaible Types
# . type checking and Conversion
# . Dynamic Typing
# . Practical example and Common Errors

# %%
a=100

# %%
### Declaring And Assigning Varaible

age=22
height=5.7
name="Rahul"
is_Students=True

## Printing the variables
print("age :",age)
print("height :",height)
print("name :",name)
# Out:
# age : 22
# height : 5.7
# name : Rahul

# %%
## Naming Conventions
## Variable names should be descriptive
## They must start with a letter or an '_' and contains letter, numbers and underscore
## varible names case sensitive

## valid varible names
first_name="Rahul"
last_name="Kumar"

# %%
# Invalid Variable
#2age=32
#first-name="rahul"
# Out:
#   Cell In[4], line 2
#     2age=32
#     ^
# SyntaxError: invalid decimal literal

# %%
## case sensitivie
name="Rahul"
Name="Kumar"

name==Name
# Out:
# False

# %%
##Understanding varaible types
##Python is dynamically typed,types of varaivble is determined at runtime

age=22#int
height=5.7#float
name="Rahul"#str
is_Students=True#boolean

print(type(name))
# Out:
# <class 'str'>

# %%
## type conversion
age=22
print(type(age))

age_str=str(age)
print(age_str)
print(type(str))
# Out:
# <class 'int'>
# 22
# <class 'type'>

# %%
#convert integer into float
age=22
age_flo=float(age)
print(age_flo)
print(type(age_flo))
# Out:
# 22.0
# <class 'float'>

# %%
name="1,2,3"
name_str=str(name)
print(name)
print(name_str)
# Out:
# 1,2,3
# 1,2,3

# %%
height=5.7
height_int=int(height)
print(height_int)
print(type(height_int))
# Out:
# 5
# <class 'int'>

# %%
## Dynamic Typing
## python allows the type of a variable to change as the program execute
var=10
print(var,type(var))

var="hello"
print(var,type(var))

var=2.4
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 2.4 <class 'float'>

# %%
## Input
age=int(input("What is the age:"))
print(age,type(age))
# Out:
# 2 <class 'int'>

# %%
## simple calculator

num1 = float(input("Enter first number:"))
num2 = float(input("Enter second number:"))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("sum:", sum)
print("difference:", difference)
print("product:", product)
print("Quotient:", quotient)
# Out:
# sum: 7.0
# difference: -3.0
# product: 10.0
# Quotient: 0.4
