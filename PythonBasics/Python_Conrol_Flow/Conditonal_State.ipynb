# %% [markdown]
# ### Conditional statemennts (if, elif, else)

# %% [markdown]
# #1. Introduction to conditional statements
# #2. if statements
# #3. else statements
# #4. elif statements
# #5. Practical Example
# #6. Common Errors and best practices

# %%
## i statements
age=20

if age>=18:
    print("you are allowed to vote in the elections")
# Out:
# you are allowed to vote in the elections

# %%
age>=18
# Out:
# True

# %%
## else
## The else statements execute a block of code if the condition in the if statements i false.

age =16

if age>=18:
    print("you are eligible for voting")
else:
    print("You are minor")
# Out:
# You are minor

# %%
## elif
## The elif statements allow you to check multiple conditions. It stand for "else if"

age=17

if age < 13:
    print("You are Child:")
elif age < 18:
    print("you are teenager")
else:
    print("You are an adult")
# Out:
# you are teenager

# %%
## nested conditional statements
## you can place one or more if, elif, else statements inside another if, elif, else statements to create nested conditional statements.

## number even,odd, negative

num=int(input("Enter the numbers:"))

if num > 0:
    print("The number is positive.")
    if num %2==0:
        print("The number is even.")
    else:
        print("The number is odd.")
else:
    print("The number is Negative and zero")
# Out:
# The number is Negative and zero

# %%
## practical Examples
## Determine the year is Leap Year using nested condition statements

year=int(input("Enter the years:"))

if year %4==0:
    if year %100==0:
        if year %400==0:
            print(year,"is a leap year")
        else:
            print(year,"is not leap year")
    else:
        print(year,"is a leap year")
else:
    print(year,"is not leap year")
# Out:
# 2022 is not leap year

# %%
## Assigment
## Simple Calculator
## Take user input

num1=float(input("Enter First Number:"))
num2=float(input("Enter second Number:"))
operation=input("Enter operation (+, -, *, /): ")

# perform the request operation

if operation == '+':
    result = num1 + num2
elif operation == '-':
    result = num1 - num2
elif operation == '*':
    result = num1 * num2
elif operation == '/':
    if num2 != 0:
        result = num1 / num2
    else:
        result = "Error! Division by zero."
else:
    result= "Invalid Operation."
    
print("Result", result)
# Out:
# Result 9.0

# %%
## Determine the ticket price based on age and whether the person is student .
# Ticker pricing based on age and student status

# take user input
age = int(input("Enter your age: "))
is_students = input("Are you a students? (yes/no):").lower()

# determine ticket price
if age < 5:
    price = "free"
elif age <=12:
    price = "$10"
elif age <= 17:
    if is_student == 'yes':
        price = "$12"
    else:
        price = "$15"
elif age <=64:
    if is_students == 'yes':
        price = "$18"
    else:
        price = "$25"
else:
    price = "$20"
    
print("Ticket price:", price)
# Out:
# Ticket price: $10
