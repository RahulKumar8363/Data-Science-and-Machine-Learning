# %% [markdown]
#  Syntax refers to the set of rules that define the combination of symbols that are cosider to be correctly structred program in a laguage . In simple term, syntax is about the correct arragement of words and symbols ina code.

# %% [markdown]
# Semantics refers to the meaning or the interpretation of the sysmbols, characters,and commands in a laguage.It is about what the code is supposed to do when it run.

# %%
## Python Case Sensitivity
name="Rahul"
Name="Pawan"

print(name)
print(Name)
# Out:
# Rahul
# Pawan

# %%
## Indentation-Python use indentation to define block of code. Consistent use of space (commonly 4) or a tab is requires
###This means that all the statements within a block must be indented at the same level

age=32
if age>30:
    
    print(age)
    
print(age)
# Out:
# 32
# 32

# %%
## Line Continuation

total=1+2+3+4+5\
    +6+7+8+9

print(total)
# Out:
# 45

# %%
## Multiple Statements on a single line
x=5;y=10;z=x+y
print(y)
# Out:
# 10

# %%
##Understand Semantics In Python
# variavble assigment
age=32
name="Rahul"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## type Interface
variable=10
print(type(variable))
variable="rahul"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# Code example of indentation
if True:
    print("Correct Indentation")
    if False:
        print("This ont Print")
    print("This will print")
print("Ouutside the if block")
# Out:
# Correct Indentation
# This will print
# Ouutside the if block
